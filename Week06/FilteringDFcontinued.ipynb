# %%
import pandas as pd

# %%
titanic_df= pd.read_csv("titanic_train.csv")
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.Cabin.isna().sum()
# Out:
# np.int64(687)

# %%
non_empty_cabin= titanic_df[ titanic_df.Cabin.notna()]
non_empty_cabin.shape
# Out:
# (204, 12)

# %%
null_cabin= titanic_df[titanic_df.Cabin.notnull()]
null_cabin.shape
# Out:
# (204, 12)

# %%
#duplicate data
duplicate_ticket =titanic_df[titanic_df.duplicated(subset="Ticket", keep= "first")] #means passenger sharing the same tickets will return as true
duplicate_ticket.tail()
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880   Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 885           Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 888       Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch      Ticket     Fare Cabin Embarked
# 876      0        7534   9.8458   NaN        S
# 879      1       11767  83.1583   C50        C
# 880      1      230433  26.0000   NaN        S
# 885      5      382652  29.1250   NaN        Q
# 888      2  W./C. 6607  23.4500   NaN        S

# %%
titanic_df[titanic_df.Ticket=="349909"]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 24            25         0       3
# 374          375         0       3
# 567          568         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 7                 Palsson, Master. Gosta Leonard    male   2.0      3      1
# 24                 Palsson, Miss. Torborg Danira  female   8.0      3      1
# 374                   Palsson, Miss. Stina Viola  female   3.0      3      1
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
#
#      Ticket    Fare Cabin Embarked
# 7    349909  21.075   NaN        S
# 24   349909  21.075   NaN        S
# 374  349909  21.075   NaN        S
# 567  349909  21.075   NaN        S

# %%
titanic_df[titanic_df.Ticket.isin(["349909"])]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 24            25         0       3
# 374          375         0       3
# 567          568         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 7                 Palsson, Master. Gosta Leonard    male   2.0      3      1
# 24                 Palsson, Miss. Torborg Danira  female   8.0      3      1
# 374                   Palsson, Miss. Stina Viola  female   3.0      3      1
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
#
#      Ticket    Fare Cabin Embarked
# 7    349909  21.075   NaN        S
# 24   349909  21.075   NaN        S
# 374  349909  21.075   NaN        S
# 567  349909  21.075   NaN        S

# %%
titanic_df[titanic_df.isin(
    {"Ticket": ["349909"]}
)]
# Out:
#      PassengerId  Survived  Pclass Name  Sex  Age  SibSp  Parch Ticket  Fare  \
# 0            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 1            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 2            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 3            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 4            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# ..           ...       ...     ...  ...  ...  ...    ...    ...    ...   ...
# 886          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 887          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 888          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 889          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 890          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
#
#     Cabin Embarked
# 0     NaN      NaN
# ...

# %%
#show name and age of upto "10" column
titanic_df.loc[:10, ["Name", "Age"]]
# Out:
#                                                  Name   Age
# 0                             Braund, Mr. Owen Harris  22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss. Laina  26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                            Allen, Mr. William Henry  35.0
# 5                                    Moran, Mr. James   NaN
# 6                             McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master. Gosta Leonard   2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0

# %%
#last passenger age
titanic_df.loc[890, "Age"]
# Out:
# np.float64(32.0)
