# %%
import pandas as pd
titanic_df= pd.read_csv("titanic_train.csv")

# %% [markdown]
# 1. Bar Graph

# %%
titanic_df.value_counts(subset= ["Sex", "Survived"]).plot(
    kind="bar",
    title="Count of Suvived Passengers",
    figsize=(4,3),
    legend=True,
    xlabel= "survived (0=no, 1=yes)",
    ylabel="no. of passengers",
    grid=False,
    yticks=range(0,600,50),
    colormap="Pastel2"
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 12
#       8     grid=False,
#       9     yticks=range(0,600,50),
#      10     colormap="Pastel2"
#      11     )
# ---> 12 ax.bar_label(ax_containers[0],padding=2)
#
# NameError: name 'ax' is not defined

# %%
ax= pd.crosstab(
titanic_df["Sex"], titanic_df["Survived"]
).plot(
    kind= "bar"
)
ax.bar_label(ax.containers[0],padding=2)
# titanic_df.value_counts(subset= ["Sex", "Survived"])in.plot(
#     kind="bar",
#     title="Count of Suvived Passengers",
#     figsize=(4,4),
#     legend=True,
#     xlabel= "survived (0=no, 1=yes)",
#     ylabel="no. of passengers",
#     grid=False,
#     yticks=range(0,600,50),
#     colormap="Pastel2"
#     )
# Out:
# [Text(0, 2, '81'), Text(0, 2, '468')]

# %% [markdown]
# Pie chart

# %%
group_by_embarked = titanic_df.groupby(by="Embarked")
group_by_embarked.count()
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Embarked
# C                 168       168     168   168  168  130    168    168     168
# Q                  77        77      77    77   77   28     77     77      77
# S                 644       644     644   644  644  554    644    644     644
#
#           Fare  Cabin
# Embarked
# C          168     69
# Q           77      4
# S          644    129

# %%
group_by_embarked.count().plot(
    kind= "pie",
    y= "Survived",
    title= "Count of Passengers according to Pclass",
    autopct= "%.2f%%", #syntax %"places of integer"."decimal placed how many"f%final%to show "%"
    startangle=90
)
# Out:
# <Axes: title={'center': 'Count of Passengers according to Pclass'}>
