# %%
import pandas as pd
titanic_df= pd.read_csv("titanic_train.csv")

# %%
titanic_df.drop("PassengerId", axis=1, inplace=True)
# titanic_df.drop(columns=["PassengerId", "Name"], inplace=True) #another approach where you dont have to apecify axis if you use columns

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
#Dropping a row
titanic_df.drop([2,4], axis=0, inplace=False)
# titanic_df.drop(index=[2,4], inplace=False)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
#inserting or replacing a column
initial= []
# for name in titanic_df.Name:
#     if ("Mr." in name):
#        initial.append("Mr.")
#     elif ("Mrs." in name):
#         initial.append("Mrs.")
#     elif ("Miss." in name):
#         initial.append("Miss.")
    

initial= [name.split(",")[-1].split(".")[0].strip() for name in titanic_df.Name]
print(initial)
# Out:
# ['Mr', 'Mrs', 'Miss', 'Mrs', 'Mr', 'Mr', 'Mr', 'Master', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mr', 'Mr', 'Miss', 'Mrs', 'Master', 'Mr', 'Mrs', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Don', 'Mrs', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mr', 'Miss', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Mrs', 'Master', 'Mr', 'Mrs', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Master', 'Mr', 'Miss', 'Mr', 'Master', 'Mr', 'Master', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Master', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mr', 'Miss', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Master', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mrs', 'Miss', 'Mrs', 'Mr', 'Mr', 'Mr', '
# ...

# %%
# titanic_df["Name"]=initial #this one replaces in place of the existing column
titanic_df["Initials"]=initial #this creates a new column if not already exists

# %%
titanic_df.head(5)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   Initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %%
# titanic_df.insert(loc=3, column="Initials", value=initial)

# %%
# titanic_df.drop(columns="Title", inplace=True)
titanic_df.head(5)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   Initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %%
#insert a new row
# titanic_df.loc[891,:]=[ 0,3, "Braund, Mr. Owen Harris", "Mr", "male", 22.0,1,0, "A/5 21171", 7.2500, pd.NA, "S"]
titanic_df.tail(5)
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 886         0       2                     Montvila, Rev. Juozas    male  27.0
# 887         1       1              Graham, Miss. Margaret Edith  female  19.0
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889         1       1                     Behr, Mr. Karl Howell    male  26.0
# 890         0       3                       Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch      Ticket   Fare Cabin Embarked Initials
# 886      0      0      211536  13.00   NaN        S      Rev
# 887      0      0      112053  30.00   B42        S     Miss
# 888      1      2  W./C. 6607  23.45   NaN        S     Miss
# 889      0      0      111369  30.00  C148        C       Mr
# 890      0      0      370376   7.75   NaN        Q       Mr

# %% [markdown]
# ### Handling null or NaN or NA values

# %%
titanic_df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# Initials      0
# dtype: int64

# %% [markdown]
# 1. Removing Null values
#         only when a few information is lost (like embarked). cant remove something like Age or Cabin row data
#
# 2. Fill something (imputation)
#
#
# 3. Nul as new feature (Feature engineering)
#
# 0-> column wise

# %%
titanic_df.dropna(subset= "Embarked", axis=0, ignore_index=True, inplace=True)

# %%
titanic_df.shape
# Out:
# (889, 12)

# %%
#null value as feature
titanic_df.Cabin=titanic_df.Cabin.notna().astype(int)

# %%
titanic_df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin         0
# Embarked      0
# Initials      0
# dtype: int64

# %%
titanic_df.head(5)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500      0        S
# 1  female  38.0      1      0          PC 17599  71.2833      1        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250      0        S
# 3  female  35.0      1      0            113803  53.1000      1        S
# 4    male  35.0      0      0            373450   8.0500      0        S
#
#   Initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %%
# Fill Null values
titanic_df_fillAge = titanic_df.copy()

titanic_df_fillAge.loc[:, "Age"] = titanic_df_fillAge["Age"].fillna(
    value=titanic_df["Age"].median()
)

titanic_df_fillAge.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# Initials    0
# dtype: int64

# %%
# Inputation of age wrt initials
group_by_initial= titanic_df.groupby(by= "Initials")

# %%
Median_age= group_by_initial["Age"].transform("median")

# %%
Median_age
# Out:
# 0      30.0
# 1      35.0
# 2      21.0
# 3      35.0
# 4      30.0
#        ...
# 884    46.5
# 885    21.0
# 886    21.0
# 887    30.0
# 888    30.0
# Name: Age, Length: 889, dtype: float64

# %%
titanic_df_fillAge_with_initial= titanic_df.copy()

titanic_df_fillAge_with_initial.loc[:, "Age"]= titanic_df_fillAge_with_initial["Age"].fillna(Median_age)

# %%
titanic_df_fillAge_with_initial.Age.plot

# %%
titanic_df.Initials = titanic_df.Initials.replace(to_replace=["Rev", "Col", "Major", "Capt", "Jonkheer", "Don",  "Sir"]
                            , value="Mr").value_counts()

# %%
titanic_df.Initials =titanic_df.Initials.replace({"Mlle": "Miss", "Ms": "Miss", "Mme": "Mrs", "Countess": "Mrs", "Lady":"Mrs"})

# %%
titanic_df.Initials.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
titanic_df.rename(columns= {"Title":"Initials"}, inplace=True)
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500      0        S
# 1  female  38.0      1      0          PC 17599  71.2833      1        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250      0        S
# 3  female  35.0      1      0            113803  53.1000      1        S
# 4    male  35.0      0      0            373450   8.0500      0        S
#
#    Initials
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# ### Outlier Handling

# %%
q1= titanic_df_fillAge_with_initial.Age.quantile(q=0.25)
q3= titanic_df_fillAge_with_initial.Age.quantile(q=0.75)

iqr= q3-q1

maximum= q3+(1.5*iqr)
minimum= q1-(1.5*iqr)

# %%
titanic_df_fillAge_with_initial[
    (titanic_df_fillAge_with_initial.Age <=maximum ) | (titanic_df_fillAge_with_initial.Age >=minimum)
].shape
# Out:
# (889, 12)

# %%
titanic_df_fillAge_outlierAge= titanic_df_fillAge_with_initial[
    (titanic_df_fillAge_with_initial.Age <= maximum ) | (titanic_df_fillAge_with_initial.Age >=minimum)
]
titanic_df_fillAge_outlierAge.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500      0        S
# 1  female  38.0      1      0          PC 17599  71.2833      1        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250      0        S
# 3  female  35.0      1      0            113803  53.1000      1        S
# 4    male  35.0      0      0            373450   8.0500      0        S
#
#   Initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %%
titanic_df_fillAge_outlierAge.Fare.plot(kind="box", vert=False, figsize= (12,2))
# Out:
# <Axes: >

# %%
q1= titanic_df_fillAge_outlierAge.Fare.quantile(q=0.25)
q3= titanic_df_fillAge_outlierAge.Fare.quantile(q=0.75)

iqr= q3-q1

maximum= q3+(1.5*iqr)
minimum= q1-(1.5*iqr)

print(minimum , maximum )
# Out:
# -26.7605 65.6563
