# %%
# %pip install scipy
# Out:
# Collecting scipy
#   Using cached scipy-1.18.1-cp313-cp313-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in d:\study material\Project\DSandML\.venv\Lib\site-packages (from scipy) (2.5.2)
# Using cached scipy-1.18.1-cp313-cp313-win_amd64.whl (36.6 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
x= np.random.standard_t(500, size=1000)
x[:15]
# Out:
# array([-0.37794371,  0.47656756,  0.87658718,  0.93398514,  1.15336133,
#         0.49356939, -1.44919673,  0.51440228, -0.28189894,  0.62199432,
#         0.90347088,  1.89673135,  0.77384095, -0.45606151, -0.57057414])

# %%
_mean=np.mean(x)
print(f"Mean of x= {_mean}")
plt.hist(x, bins=20,color='blue')
# Out:
# Mean of x= 0.040967284483730486
# (array([  1.,   5.,   8.,  18.,  39.,  49., 101., 123., 131., 140., 137.,
#          90.,  70.,  45.,  21.,  17.,   4.,   0.,   0.,   1.]),
#  array([-3.27543979, -2.91407964, -2.5527195 , -2.19135935, -1.8299992 ,
#         -1.46863906, -1.10727891, -0.74591876, -0.38455861, -0.02319847,
#          0.33816168,  0.69952183,  1.06088197,  1.42224212,  1.78360227,
#          2.14496242,  2.50632256,  2.86768271,  3.22904286,  3.59040301,
#          3.95176315]),
#  <BarContainer object of 20 artists>)

# %%
_median=np.median(x)
print(f"Median of x= {_median}")
plt.hist(x, bins=20,color='green')
# Out:
# Median of x= 0.025754444072202107
# (array([  1.,   5.,   8.,  18.,  39.,  49., 101., 123., 131., 140., 137.,
#          90.,  70.,  45.,  21.,  17.,   4.,   0.,   0.,   1.]),
#  array([-3.27543979, -2.91407964, -2.5527195 , -2.19135935, -1.8299992 ,
#         -1.46863906, -1.10727891, -0.74591876, -0.38455861, -0.02319847,
#          0.33816168,  0.69952183,  1.06088197,  1.42224212,  1.78360227,
#          2.14496242,  2.50632256,  2.86768271,  3.22904286,  3.59040301,
#          3.95176315]),
#  <BarContainer object of 20 artists>)
