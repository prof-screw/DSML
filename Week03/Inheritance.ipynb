# %%
class Parent:
    def __init__(self, name, age):
        self.name= name
        self.age= age
    
    def intro(self):
        return f"hello, I am {self.name}"
    
class child(Parent):
    ...
    
child1= child("ram", 15)
child1.intro()
# Out:
# 'hello, I am ram'

# %%
class Animal:
    
    def __init__(self, name, age):
        self.name= name
        self.age= age
        
    def intro(self):
        print(f"Hello, i am {self.name}")

# %%
class cat(Animal):
    def __init__(self, name1, age1, color):
        super().__init__(name1,age1)
        self.color= color
        
    def details(self):
        print(f"{self.color} cat: \n{self.name} \n age: {Animal.age1}")
        
child1=cat("kitty", 15, "Orange")
child1.details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 10
#       6     def details(self):
#       7         print(f"{self.color} cat: \n{self.name} \n age: {Animal.age1}")
#       8
#       9 child1=cat("kitty", 15, "Orange")
# ---> 10 child1.details()
#
# Cell In[7], line 7, in cat.details(self)
#       6     def details(self):
# ----> 7         print(f"{self.color} cat: \n{self.name} \n age: {Animal.age1}")
#
# AttributeError: type object 'Animal' has no attribute 'age1'

# %%
class Parent1:
    def func1(self):
        print("this is parent 1")
        
class Parent2:
    def func2(self):
        print("this is parent 2")
        
class Parent3:
    def func1(self):
        print("this is parent 3")

# %%
class Child(Parent1, Parent2, Parent3):
    def func4(self):
        print("this is child")
        
obj= Child()
obj.func4()
# Out:
# this is child

# %%
class A:
    def method_a(self):
        print("This is method from Class A")

class B(A):
    def methdo_b(self):
        print("This is method crom class B")
        
class C(B):
    def method_c(self):
        print("this si method from class C")
