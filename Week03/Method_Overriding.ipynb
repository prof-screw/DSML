# %%
class Animal:
        def sound(self):
            print("Making Sound")

# %%
class Dog(Animal):
    def sound(self):
        super().sound() 
        print("Dog makes woof sound")

# %%
dog= Dog()

dog.sound()
# Out:
# Making Sound
# Dog makes woof sound
