# %%
import numpy as np

# %%
a= np.random.randint(10,30, size= (5,2,3))

# %%
a.shape
# Out:
# (5, 2, 3)

# %%
a.ndim
# Out:
# 3

# %%
a.dtype
# Out:
# dtype('int32')

# %%
a.T
# Out:
# array([[[20, 20, 10, 17, 23],
#         [10, 21, 15, 15, 21]],
#
#        [[22, 20, 15, 18, 19],
#         [27, 18, 19, 11, 19]],
#
#        [[21, 11, 28, 22, 22],
#         [17, 28, 20, 16, 10]]], dtype=int32)

# %%
a.size
# Out:
# 30

# %%
a= np.random.randint(10,50, size=(5,4), dtype="int16")
a
# Out:
# array([[11, 22, 16, 27],
#        [24, 42, 49, 14],
#        [41, 39, 14, 31],
#        [23, 34, 15, 47],
#        [15, 30, 38, 27]], dtype=int16)

# %%
a.reshape(5,2,2)
a.reshape(5,2,-1) #checks however remaining automatically
# Out:
# array([[[11, 22],
#         [16, 27]],
#
#        [[24, 42],
#         [49, 14]],
#
#        [[41, 39],
#         [14, 31]],
#
#        [[23, 34],
#         [15, 47]],
#
#        [[15, 30],
#         [38, 27]]], dtype=int16)

# %%
a.flatten() #turns it to linear shape like a list
# Out:
# array([11, 22, 16, 27, 24, 42, 49, 14, 41, 39, 14, 31, 23, 34, 15, 47, 15,
#        30, 38, 27], dtype=int16)

# %%
a.sum()
# Out:
# np.int64(559)

# %%
a.sum(axis=0) #vertical add
# Out:
# array([114, 167, 132, 146])

# %%
a.sum(axis=1) #horizontal add
# Out:
# array([ 76, 129, 125, 119, 110])

# %%
a.trace() #diagonal sum
# Out:
# np.int64(114)

# %%
a.cumsum(axis=1)
# Out:
# array([[ 11,  33,  49,  76],
#        [ 24,  66, 115, 129],
#        [ 41,  80,  94, 125],
#        [ 23,  57,  72, 119],
#        [ 15,  45,  83, 110]])

# %%
a.prod(axis=0)
# Out:
# array([ 3734280, 36756720,  6256320, 14870142])

# %%
a.cumprod(axis=1)
# Out:
# array([[    11,    242,   3872, 104544],
#        [    24,   1008,  49392, 691488],
#        [    41,   1599,  22386, 693966],
#        [    23,    782,  11730, 551310],
#        [    15,    450,  17100, 461700]])

# %%
a
# Out:
# array([[11, 22, 16, 27],
#        [24, 42, 49, 14],
#        [41, 39, 14, 31],
#        [23, 34, 15, 47],
#        [15, 30, 38, 27]], dtype=int16)

# %%
a.argmax() #index of max value
# Out:
# np.int64(6)

# %%
a.clip(min=20, max=40)
# Out:
# array([[20, 22, 20, 27],
#        [24, 40, 40, 20],
#        [40, 39, 20, 31],
#        [23, 34, 20, 40],
#        [20, 30, 38, 27]], dtype=int16)

# %%
arr1=np.random.randint(1,100,size=(3,3))
arr2=np.random.randint(1,100,size=(3,3))

# %%
arr1,arr2
# Out:
# (array([[50, 96, 88],
#         [74, 90, 60],
#         [ 9, 24, 33]], dtype=int32),
#  array([[16, 23, 78],
#         [49, 67, 68],
#         [45, 21, 43]], dtype=int32))

# %%
np.concatenate([arr1,arr2])
np.concatenate([arr1,arr2], axis=0) #it's the default so dont have to do this
np.concatenate([arr1,arr2], axis=1)
# Out:
# array([[50, 96, 88, 16, 23, 78],
#        [74, 90, 60, 49, 67, 68],
#        [ 9, 24, 33, 45, 21, 43]], dtype=int32)

# %%
np.vstack([arr1,arr2])
np.hstack([arr1,arr2])
# Out:
# array([[50, 96, 88, 16, 23, 78],
#        [74, 90, 60, 49, 67, 68],
#        [ 9, 24, 33, 45, 21, 43]], dtype=int32)
