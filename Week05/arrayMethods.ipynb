# %%
import numpy as np

# %%
a= np.random.randint(10,50, size=(5,4), dtype="int16")
np.shape(a)
# Out:
# (5, 4)

# %%
arr= np.array([1,2,3,4,5])

# %%
print(arr[3])
# Out:
# 4

# %%
arr[2::1]
# Out:
# array([3, 4, 5])

# %%
arr[::-1]
# Out:
# array([5, 4, 3, 2, 1])

# %%
a
# Out:
# array([[24, 37, 36, 38],
#        [25, 24, 41, 14],
#        [25, 31, 30, 46],
#        [23, 20, 24, 27],
#        [41, 31, 25, 38]], dtype=int16)

# %%
a[2,-1]
# Out:
# np.int16(46)

# %%
a[-1,-1]
# Out:
# np.int16(38)

# %%
a[:-1]
# Out:
# array([[24, 37, 36, 38],
#        [25, 24, 41, 14],
#        [25, 31, 30, 46],
#        [23, 20, 24, 27]], dtype=int16)

# %% [markdown]
# SLICING 2D ARRAY
# First rows sliced and after columns

# %%
a[::]
# Out:
# array([[24, 37, 36, 38],
#        [25, 24, 41, 14],
#        [25, 31, 30, 46],
#        [23, 20, 24, 27],
#        [41, 31, 25, 38]], dtype=int16)
