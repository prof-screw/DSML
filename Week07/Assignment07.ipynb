# %% [markdown]
# ### **Coding Assignment: Data Exploration and Visualization Using Pandas**
#
# ### **Dataset 01:**
# Use the [Iris Species dataset](https://www.kaggle.com/uciml/iris) from Kaggle, which contains measurements of different species of iris flowers.

# %% [markdown]
# #### **Instructions:**
#
# 1. **Importing the Dataset:**
#    - Load the dataset into a pandas DataFrame.
#    - Display the first 5 rows of the dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
iris_filepath= '../Dataset/iris.csv'

iris_df= pd.read_csv(iris_filepath)

iris_df.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %% [markdown]
# 2. **Basic Data Exploration:**
#    - **Data Summary:**
#      - Display basic information about the dataset, including the number of rows and columns, data types of each column, and memory usage.
#      - Generate descriptive statistics for the numerical columns (e.g., mean, median, standard deviation).
#    - **Check for Missing Values:**
#      - Identify any missing values in the dataset and explain how you would handle them if there were any.
#    - **Value Counts:**
#      - Display the count of each unique species in the `species` column.

# %%
#data summary

print(f"(Rows, Columns)={iris_df.shape}")
# Out:
# (Rows, Columns)=(150, 6)

# %%
print("Here, the 'dtype' column represents the data type of each column. And the memory usage rate is shown as 8.3KB\n")
iris_df.info()
# Out:
# Here, the 'dtype' column represents the data type of each column. And the memory usage rate is shown as 8.3KB
#
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 150 non-null    int64
#  1   Sepal Length (cm)  150 non-null    float64
#  2   Sepal Width (cm)   150 non-null    float64
#  3   Petal Length (cm)  150 non-null    float64
#  4   Petal Width (cm)   150 non-null    float64
#  5   Species            150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
iris_df.describe()
# Out:
#                Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# count  150.000000         150.000000        150.000000         150.000000
# mean    75.500000           5.843333          3.054000           3.758667
# std     43.445368           0.828066          0.433594           1.764420
# min      1.000000           4.300000          2.000000           1.000000
# 25%     38.250000           5.100000          2.800000           1.600000
# 50%     75.500000           5.800000          3.000000           4.350000
# 75%    112.750000           6.400000          3.300000           5.100000
# max    150.000000           7.900000          4.400000           6.900000
#
#        Petal Width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
#checking for missing values
print("Here, there contains no null values in any rows or columns. If there were any missing values,\nwe could handle them by either dropping the rows with the missing data or filling them if there are too many to be dropped")
iris_df.isna().sum()
# Out:
# Here, there contains no null values in any rows or columns. If there were any missing values,
# we could handle them by either dropping the rows with the missing data or filling them if there are too many to be dropped
# Id                   0
# Sepal Length (cm)    0
# Sepal Width (cm)     0
# Petal Length (cm)    0
# Petal Width (cm)     0
# Species              0
# dtype: int64

# %%
#value counts
print(f"There are {iris_df['Species'].nunique()} unique species")
iris_df['Species'].value_counts()
# Out:
# There are 3 unique species
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 3. **Filtering and Sorting:**
#    - Filter the dataset to show only the rows where the `sepal_length` is greater than 5.0.
#    - Sort the filtered dataset by `petal_length` in descending order.

# %%
iris_df_filtered= iris_df[(iris_df['Sepal Length (cm)']>5.0)]
print(iris_df_filtered)

iris_df_filtered.sort_values(by='Petal Length (cm)', ascending=False)
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 5      6                5.4               3.9                1.7
# 10    11                5.4               3.7                1.5
# 14    15                5.8               4.0                1.2
# 15    16                5.7               4.4                1.5
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 5                 0.4     Iris-setosa
# 10                0.2     Iris-setosa
# 14                0.2     Iris-setosa
# 15                0.4     Iris-setosa
# ..                ...             ...
# 145               2.3  Iris-virginica
# 146               1.9  Iris-virginica
# 147               2.0  Iris-virginica
# 148               2.3  Iris-virginica
# 149               1.8  Iris-virginica
#
# [118 rows x 6 columns]
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 118  119                7.7               2.6                6.9
# 117  118                7.7               3.8                6.7
# 122  123                7.7               2.8                6.7
# 105  106                7.6               3.0                6.6
# 131  132                7.9               3.8                6.4
# ..   ...                ...               ...                ...
# 28    29                5.2               3.4                1.4
# 33    34                5.5               4.2                1.4
# 16    17                5.4               3.9                1.3
# 36    37                5.5               3.5                1.3
# 14    15                5.8               4.0                1.2
#
#      Petal Width (cm)         Species
# 118               2.3  Iris-virginica
# 117               2.2  Iris-virginica
# 122               2.0  Iris-virginica
# 105               2.1  Iris-virginica
# 131               2.0  Iris-virginica
# ..                ...             ...
# 28                0.2     Iris-setosa
# 33                0.2     Iris-setosa
# 16                0.4     Iris-setosa
# 36                0.2     Iris-setosa
# 14                0.2     Iris-setosa
#
# [118 rows x 6 columns]

# %% [markdown]
# 5. **Creating New Columns:**
#    - Create a new column called `sepal_petal_ratio` which is the ratio of `sepal_length` to `petal_length`.

# %%
iris_df['sepal_petal_ratio']= iris_df['Sepal Length (cm)']/ iris_df['Petal Length (cm)']

iris_df.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species  sepal_petal_ratio
# 0               0.2  Iris-setosa           3.642857
# 1               0.2  Iris-setosa           3.500000
# 2               0.2  Iris-setosa           3.615385
# 3               0.2  Iris-setosa           3.066667
# 4               0.2  Iris-setosa           3.571429

# %% [markdown]
# 6. **Data Visualization:**
#    - **Histogram:**
#      - Create a histogram to visualize the distribution of `sepal_length` values.
#    - **Scatter Plot:**
#      - Create a scatter plot with `sepal_length` on the x-axis and `petal_length` on the y-axis. Use different colors to represent different species.
#    - **Box Plot:**
#      - Create a box plot for the `sepal_width` values, grouped by `species`.

# %%
plt.title("Distribution of sepal length of Iris flowers")
sns.histplot(data=iris_df, x='Sepal Length (cm)')
# Out:
# <Axes: title={'center': 'Distribution of sepal length of Iris flowers'}, xlabel='Sepal Length (cm)', ylabel='Count'>

# %%
plt.title("Relation between sepal length and petal length of iris, by species")
sns.scatterplot(data=iris_df, x='Sepal Length (cm)', y='Petal Length (cm)', hue='Species')
# Out:
# <Axes: title={'center': 'Relation between sepal length and petal length of iris, by species'}, xlabel='Sepal Length (cm)', ylabel='Petal Length (cm)'>

# %%
sns.boxplot(data=iris_df, x='Species', y='Sepal Width (cm)')
# Out:
# <Axes: xlabel='Species', ylabel='Sepal Width (cm)'>

# %% [markdown]
# 7. **Correlation Matrix**
#    - Calculate the correlation matrix for the numerical features and create a heatmap to visualize the correlations using `seaborn`.

# %%
dataframe= pd.DataFrame(iris_df, columns=['Sepal Length (cm)','Sepal Width (cm)','Petal Length (cm)','Petal Width (cm)'])
iris_corr_matrix= dataframe.corr()
print(iris_corr_matrix)

plt.figure(figsize=(10,6))
sns.heatmap(data=iris_corr_matrix, annot=True , cmap='coolwarm')
plt.title('Correlation Matrix of Iris Numerical Features')
# Out:
#                    Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# Sepal Length (cm)           1.000000         -0.109369           0.871754
# Sepal Width (cm)           -0.109369          1.000000          -0.420516
# Petal Length (cm)           0.871754         -0.420516           1.000000
# Petal Width (cm)            0.817954         -0.356544           0.962757
#
#                    Petal Width (cm)
# Sepal Length (cm)          0.817954
# Sepal Width (cm)          -0.356544
# Petal Length (cm)          0.962757
# Petal Width (cm)           1.000000
# Text(0.5, 1.0, 'Correlation Matrix of Iris Numerical Features')

# %% [markdown]
# ---

# %% [markdown]
# ### **Dataset 02 :** [House Prices Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)
#
# The dataset includes 79 explanatory variables that describe aspects of residential homes.
#
# #### **Instructions**:
# - Use Python and Jupyter Notebook to solve the questions.
# - Ensure your code is efficient, well-commented, and follows best practices for handling missing data and outliers.
# - Use appropriate visualizations where needed and include explanations for your analysis.

# %% [markdown]
# ### **Problem 1: Data Exploration with Pandas**
# 1. Load the House Prices dataset using Pandas and perform initial exploration:
#    - Display the first and last 5 rows.
#    - Display the **data types** of each column.
#    - Check for **missing values** and calculate the percentage of missing data for each column.
#    - Summarize the **statistical properties** of the numerical columns using `describe()`.
#
# 2. Based on the dataset, identify the following:
#    - Columns that are **categorical** and **numerical**.
#    - Any potential **outliers** in the numerical columns (use visualizations like boxplots).

# %%
housing_df_filepath= '../Dataset/housing_data.csv'
housing_df= pd.read_csv(housing_df_filepath, index_col="Id")

pd.concat([housing_df.head(),housing_df.tail()])
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [10 rows x 80 columns]

# %%
housing_df.shape
# Out:
# (1460, 80)

# %%
housing_df.dtypes
# Out:
# MSSubClass         int64
# MSZoning             str
# LotFrontage      float64
# LotArea            int64
# Street               str
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType             str
# SaleCondition        str
# SalePrice          int64
# Length: 80, dtype: object

# %%
missing_counts= housing_df.isna().sum()
total_rows= len(housing_df)
percent_missing= (missing_counts/total_rows)*100
print(f"Column Name     Percent of missing data\n{percent_missing[percent_missing>0]}")
# Out:
# Column Name     Percent of missing data
# LotFrontage     17.739726
# Alley           93.767123
# MasVnrType      59.726027
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %%
housing_df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max
# MSSubClass         50.0      70.00     190.0
# LotFrontage        69.0      80.00     313.0
# LotArea          9478.5   11601.50  215245.0
# OverallQual         6.0       7.00      10.0
# OverallCond         5.0       6.00       9.0
# YearBuilt        1973.0    2000.00    2010.0
# YearRemodAdd     1994.0    2004.00    2010.0
# MasVnrArea          0.0     166.00    1600.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtUnfSF         477.5     808.00    2336.0
# TotalBsmtSF       991.5    1298.25    6110.0
# 1stFlrSF         1087.0    1391.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1464.0    1776.75    5642.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       8.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      14.0
# Fireplaces          1.0       1.00       3.0
# GarageYrBlt      1980.0    2002.00    2010.0
# GarageCars          2.0       2.00       4.0
# GarageArea        480.0     576.00    1418.0
# WoodDeckSF          0.0     168.00     857.0
# OpenPorchSF        25.0      68.00     547.0
# EnclosedPorch       0.0       0.00     552.0
# 3SsnPorch           0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      163000.0  214000.00  755000.0

# %%
numerical_col= housing_df.select_dtypes(include=["number"]).columns

categorical_col= housing_df.select_dtypes(exclude=["number"]).columns

numerical_col.shape, categorical_col.shape
# Out:
# ((37,), (43,))

# %%
plt.figure(figsize=(20, 10))

sns.boxplot(
    data=housing_df[numerical_col]
)

plt.xticks(rotation=90)
plt.title("Boxplots of Numerical Features")
plt.show()

# %% [markdown]
# ### **Problem 2: Data Manipulation with Pandas**
# 1. Filter the dataset to include only houses where the **SalePrice** is above the **90th percentile**.
# 2. Create a new **calculated column**: `Price_Per_SqFt = SalePrice / GrLivArea`.
# 3. **Group the data** by `Neighborhood` and calculate the **mean** and **median** for `SalePrice`.
# 4. Sort the dataset by `Price_Per_SqFt` and display the **top 10 rows**.

# %%
threshold=housing_df['SalePrice'].quantile(0.90)
top_houses= housing_df[housing_df['SalePrice']> threshold]

# %%
housing_df['Price_Per_SqFt']= housing_df['SalePrice']/ housing_df['GrLivArea']

# %%
housing_df.groupby('Neighborhood').SalePrice.agg(['mean', 'median'])
# Out:
#                        mean    median
# Neighborhood
# Blmngtn       194870.882353  191000.0
# Blueste       137500.000000  137500.0
# BrDale        104493.750000  106000.0
# BrkSide       124834.051724  124300.0
# ClearCr       212565.428571  200250.0
# CollgCr       197965.773333  197200.0
# Crawfor       210624.725490  200624.0
# Edwards       128219.700000  121750.0
# Gilbert       192854.506329  181000.0
# IDOTRR        100123.783784  103000.0
# MeadowV        98576.470588   88000.0
# Mitchel       156270.122449  153500.0
# NAmes         145847.080000  140000.0
# NPkVill       142694.444444  146000.0
# NWAmes        189050.068493  182900.0
# NoRidge       335295.317073  301500.0
# NridgHt       316270.623377  315000.0
# OldTown       128225.300885  119000.0
# SWISU         142591.360000  139500.0
# Sawyer        136793.135135  135000.0
# SawyerW       186555.796610  179900.0
# Somerst       225379.837209  225500.0
# StoneBr       310499.000000  278000.0
# Timber        242247.447368  228475.0
# Veenker       238772.727273  218000.0

# %%
housing_df.sort_values(by='Price_Per_SqFt').head(10)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1299          60       RL        313.0    63887   Pave   NaN      IR3
# 31            70  C (all)         50.0     8500   Pave  Pave      Reg
# 1063         190       RM         85.0    13600   Pave  Grvl      Reg
# 969           50       RM         50.0     5925   Pave   NaN      Reg
# 524           60       RL        130.0    40094   Pave   NaN      IR1
# 1293          70       RM         60.0     6600   Pave   NaN      Reg
# 199           75       RM         92.0     5520   Pave   NaN      Reg
# 411           20       RL         68.0     9571   Pave   NaN      Reg
# 496           30  C (all)         60.0     7879   Pave   NaN      Reg
# 677           70       RM         60.0     9600   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# Id                                    ...
# 1299         Bnk    AllPub    Corner  ...     Gd    NaN         NaN       0
# 31           Lvl    AllPub    Inside  ...    NaN  MnPrv         NaN       0
# 1063         Lvl    AllPub    Inside  ...    NaN    NaN         NaN       0
# 969          Lvl    AllPub    Inside  ...    NaN   GdWo         NaN       0
# 524          Bnk    AllPub    Inside  ...    NaN    NaN         NaN       0
# 1293         Lvl    AllPub    Corner  ...    NaN    NaN         NaN       0
# 199          Lvl    AllPub    Corner  ...    NaN  MnPrv         NaN       0
# 411          Lvl    AllPub    Inside  ...    NaN    NaN         NaN       0
# 496          Lvl    AllPub    Inside  ...    NaN   GdWo         NaN       0
# 677          Lvl    AllPub    Inside  ...    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice  Price_Per_SqFt
# Id
# 1299      1   2008       New        Partial     160000       28.358738
# 31        7   2008        WD         Normal      40000       30.372058
# 1063      9   2007        WD         Normal      90000       38.510911
# 969       5   2009        WD        Abnorml      37900       39.152893
# 524      10   2007       New        Partial     184750       39.510265
# 1293     12   2009        WD         Normal     107500       45.320405
# 199       7   2009        WD        Abnorml     104000       46.657694
# 411       6   2009       COD        Abnorml      60000       47.021944
# 496      11   2009        WD        Abnorml      34900       48.472222
# 677       5   2006        WD         Normal      87000       49.041714
#
# [10 rows x 81 columns]

# %% [markdown]
# ### **Problem 3: Handling Missing Data and Imputation**
# 1. Identify columns with **missing values**.
# 2. Impute the missing values:
#    - For **numerical columns**, replace missing values with the **median**.
#    - For **categorical columns**, replace missing values with the **most frequent** value.
# 3. Justify your choice of imputation methods and check if any missing data remains.

# %%
col_with_missing= housing_df.isna().columns
col_with_missing
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice',
#        'Price_Per_SqFt'],
#       dtype='str')

# %%
housing_df[numerical_col] = housing_df[numerical_col].fillna(housing_df[numerical_col].median())
print(housing_df[numerical_col].isna().sum().sum())  

housing_df[categorical_col] = housing_df[categorical_col].apply(lambda col: col.fillna(col.mode()[0]))
print(housing_df[categorical_col].isna().sum().sum())
# Out:
# 0
# 0

# %%
housing_df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Problem 4: Numpy Array Operations**
# 1. Convert the numerical columns (such as `LotArea`, `YearBuilt`, `GrLivArea`, `SalePrice`, etc.) into a **NumPy array**.
# 2. Perform the following NumPy operations on the array:
#    - Compute the **mean** and **standard deviation** of each column.
#    - Normalize the data using **min-max scaling** and **z-score normalization**.
#    - Compute the **dot product** between two numerical columns of your choice.

# %%
np.set_printoptions(suppress=True, precision=4)
numPy_arr= housing_df[numerical_col].to_numpy()
print(numPy_arr)
# Out:
# [[    60.     65.   8450. ...      2.   2008. 208500.]
#  [    20.     80.   9600. ...      5.   2007. 181500.]
#  [    60.     68.  11250. ...      9.   2008. 223500.]
#  ...
#  [    70.     66.   9042. ...      5.   2010. 266500.]
#  [    20.     68.   9717. ...      4.   2010. 142125.]
#  [    20.     75.   9937. ...      6.   2008. 147500.]]

# %%
col_means= np.mean(numPy_arr, axis=0)
col_stds= np.std(numPy_arr, axis=0)

print(f"The mean of column are: {col_means}")
print(f"The standard deviation of column are: {col_stds}")
# Out:
# The mean of column are: [    56.8973     69.8637  10516.8281      6.0993      5.5753   1971.2678
#    1984.8658    103.1171    443.6397     46.5493    567.2404   1057.4295
#    1162.6267    346.9925      5.8445   1515.4637      0.4253      0.0575
#       1.5651      0.3829      2.8664      1.0466      6.5178      0.613
#    1978.589       1.7671    472.9801     94.2445     46.6603     21.9541
#       3.4096     15.061       2.7589     43.489       6.3219   2007.8158
#  180921.1959]
# The standard deviation of column are: [   42.2861    22.0201  9977.8461     1.3825     1.1124    30.1926
#     20.6383   180.6695   455.9419   161.264    441.7156   438.5551
#    386.4553   436.3789    48.6064   525.3004     0.5187     0.2387
#      0.5507     0.5027     0.8155     0.2203     1.6248     0.6444
#     23.9888     0.7471   213.7316   125.2959    66.2333    61.0982
#     29.3073    55.7383    40.1635   495.9531     2.7027     1.3276
#  79415.2919]

# %%
min_val = np.min(numPy_arr, axis=0)
max_val = np.max(numPy_arr, axis=0)
scaled_data = (numPy_arr - min_val) / (max_val - min_val)

print("Original Data:", numPy_arr)
print("Min-Max Scaled Data:", scaled_data)
# Out:
# Original Data: [[    60.     65.   8450. ...      2.   2008. 208500.]
#  [    20.     80.   9600. ...      5.   2007. 181500.]
#  [    60.     68.  11250. ...      9.   2008. 223500.]
#  ...
#  [    70.     66.   9042. ...      5.   2010. 266500.]
#  [    20.     68.   9717. ...      4.   2010. 142125.]
#  [    20.     75.   9937. ...      6.   2008. 147500.]]
# Min-Max Scaled Data: [[0.2353 0.1507 0.0334 ... 0.0909 0.5    0.2411]
#  [0.     0.2021 0.0388 ... 0.3636 0.25   0.2036]
#  [0.2353 0.161  0.0465 ... 0.7273 0.5    0.2619]
#  ...
#  [0.2941 0.1541 0.0362 ... 0.3636 1.     0.3216]
#  [0.     0.161  0.0393 ... 0.2727 1.     0.1489]
#  [0.     0.1849 0.0404 ... 0.4545 0.5    0.1564]]

# %%
z_standardized= (numPy_arr -col_means)/ col_stds

print("Original Data:", numPy_arr)
print("Zcore Normalized Data:", z_standardized)
# Out:
# Original Data: [[    60.     65.   8450. ...      2.   2008. 208500.]
#  [    20.     80.   9600. ...      5.   2007. 181500.]
#  [    60.     68.  11250. ...      9.   2008. 223500.]
#  ...
#  [    70.     66.   9042. ...      5.   2010. 266500.]
#  [    20.     68.   9717. ...      4.   2010. 142125.]
#  [    20.     75.   9937. ...      6.   2008. 147500.]]
# Zcore Normalized Data: [[ 0.0734 -0.2209 -0.2071 ... -1.5991  0.1388  0.3473]
#  [-0.8726  0.4603 -0.0919 ... -0.4891 -0.6144  0.0073]
#  [ 0.0734 -0.0846  0.0735 ...  0.9909  0.1388  0.5362]
#  ...
#  [ 0.3099 -0.1755 -0.1478 ... -0.4891  1.6452  1.0776]
#  [-0.8726 -0.0846 -0.0802 ... -0.8591  1.6452 -0.4885]
#  [-0.8726  0.2333 -0.0581 ... -0.1191  0.1388 -0.4208]]

# %%
dot_product= np.dot(numPy_arr[:,2], numPy_arr[:,22] )
print("The dot product of column 2 and 22 = ", dot_product)
# Out:
# The dot product of column 2 and 22 =  104575797.0

# %% [markdown]
# ### **Problem 5: Data Visualization**
# Using Matplotlib and/or Seaborn, visualize the following:
# 1. **Distribution** of `SalePrice` using a **histogram**.
# 2. **Box plot** of `SalePrice` grouped by `OverallQual` (overall quality of the house).
# 3. **Scatter plot** between `GrLivArea` (Above-ground living area) and `SalePrice`. Analyze the relationship.
# 4. Plot a **correlation heatmap** for the numerical columns.

# %%
plt.title("Sales Prices distribution")
sns.histplot(data=housing_df, x='SalePrice')
# Out:
# <Axes: title={'center': 'Sales Prices distribution'}, xlabel='SalePrice', ylabel='Count'>

# %%
plt.figure(figsize=(12, 6))
plt.title("sales prices by overall quality")
sns.boxplot(data=housing_df,y='SalePrice', x= 'OverallQual')

plt.xlabel('Overall quality')
plt.ylabel('Sales price')
# Out:
# Text(0, 0.5, 'Sales price')

# %%
sns.scatterplot(data=housing_df, x= 'GrLivArea', y= 'SalePrice')
plt.title("Relation between Saleprice and Above ground living area")

print("The below figure shows that sale price and Above ground living area has a positive correlation ")
# Out:
# The below figure shows that sale price and Above ground living area has a positive correlation

# %%
corr_matrix = housing_df[numerical_col].corr()

plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f',
            vmin=-1, vmax=1, square=True, annot_kws={"size": 6})
plt.title('Correlation Matrix of Numerical Features')

plt.show()

# %% [markdown]
# ### **Problem 6: Aggregation and Transformation**
# 1. Perform a **groupby** operation on `Neighborhood` and calculate the **mean** and **median** for `SalePrice`.
# 2. Use the `apply()` function to create a custom transformation for `SalePrice` (e.g., scaling or transformation).
# 3. Aggregate multiple statistical values (e.g., **mean**, **median**, and **count**) for `SalePrice` grouped by `OverallQual`.
