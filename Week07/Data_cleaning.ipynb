# %%
import pandas as pd

titanic_df= pd.read_csv("clean_titanic_train.csv")

# %%
data= data.astype({"Age":"int32"})
data.Age=abs(data.Age)
data
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 3             3         1       1
# 4             4         0       3
# ..          ...       ...     ...
# 884         884         0       2
# 885         885         1       1
# 886         886         0       3
# 887         887         1       1
# 888         888         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
data[data.Sex.isin(["M","F"])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Initials]
# Index: []
