# %%
import pandas as pd

titanic_df = pd.read_csv("Encoded_titanic_train.csv")

# %%
titanic_df
# Out:
#      Unnamed: 0.1  Unnamed: 0  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0               0           0         0       2    male  22.0      1      0
# 1               1           1         1       0  female  38.0      1      0
# 2               2           2         1       2  female  26.0      0      0
# 3               3           3         1       0  female  35.0      1      0
# 4               4           4         0       2    male  35.0      0      0
# ..            ...         ...       ...     ...     ...   ...    ...    ...
# 884           884         884         0       1    male  27.0      0      0
# 885           885         885         1       0  female  19.0      0      0
# 886           886         886         0       2  female  21.0      1      2
# 887           887         887         1       0    male  26.0      0      0
# 888           888         888         0       2    male  32.0      0      0
#
#         Fare  Cabin Embarked
# 0     7.2500      0        S
# 1    71.2833      1        C
# 2     7.9250      0        S
# 3    53.1000      1        S
# 4     8.0500      0        S
# ..       ...    ...      ...
# 884  13.0000      0        S
# 885  30.0000      1        S
# 886  23.4500      0        S
# 887  30.0000      1        C
# 888   7.7500      0        Q
#
# [889 rows x 11 columns]

# %%
min_fare= titanic_df.Fare.min()
max_fare= titanic_df.Fare.max()

# %%
norm_fare= (titanic_df.Fare - min_fare)/ (max_fare-min_fare)

# %%
norm_fare.describe()
# Out:
# count    889.000000
# mean       0.062649
# std        0.097003
# min        0.000000
# 25%        0.015412
# 50%        0.028213
# 75%        0.060508
# max        1.000000
# Name: Fare, dtype: float64

# %%
norm_fare.plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
titanic_df.Fare.plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
mean_fare= titanic_df.Fare.mean()
std_fare= titanic_df.Fare.std()

# %%
norm_fare= (titanic_df.Fare - mean_fare)/ std_fare

# %%
norm_fare.describe()
# Out:
# count    8.890000e+02
# mean     1.358743e-16
# std      1.000000e+00
# min     -6.458409e-01
# 25%     -4.869637e-01
# 50%     -3.549973e-01
# 75%     -2.206712e-02
# max      9.663111e+00
# Name: Fare, dtype: float64

# %%
norm_fare.plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>
