# %%
print ("hello world")
# Out:
# hello world

# %%
number= 1221
number2= -1221
number3= 12.21
number4= 3+ 4j

# %%
# type(number)
# type(number2)
# type(number3)
type(number4)
# Out:
# complex

# %%
number5= float(12) #constructing float from integer

# %%
type(number5)
# Out:
# float

# %%
number5= 6**2
print(number5)
# Out:
# 36

# %%
number5= 69_696_969 #used for big numbers to make it more readable

# %%
import math
math.comb(5, 2)
# Out:
# 10

# %%
math.dist((1, 2, 7), (4, 6, 1)) #distance between two points
# Out:
# 7.810249675906654

# %%
round(math.pi, 4)
# Out:
# 3.1416

# %%
name = "Batman"
type(name)
# Out:
# str

# %%
x= str("oooooooooooooBonjour  ")
# x.lstrip() #removes leading spaces
# x.rstrip()
x.strip("o")
# Out:
# 'Bonjour  '

# %%
x.split("j") #splits string into list based on a string
# Out:
# ['oooooooooooooBon', 'our  ']

# %%
email= "student001@skill.com"
email.endswith("@skill.com") #checks if string ends with a certain string
# Out:
# True

# %%
x.split("j")[0]#starts from the beginning of the list and goes forward
x.split("j")[-1]# starts from the end of the list and goes backwards
# Out:
# 'our  '

# %%
x="Batman , Bruce Wayne"
x[0:-1:2] #slices string from 0 to -1 with a step of 2
# Out:
# 'Bta  rc an'

# %%
text= "radar"
text==text[::-1] #reverses the string
# Out:
# True

# %%
name="Alice"
msg_template = f"Hello {name}, welcome to the world of Python!"#replaces {} with the value of name
print(msg_template)
# Out:
# Hello Alice, welcome to the world of Python!
