# %%
import random

# %%
random.random()
# Out:
# 0.6567234671885627

# %%
random.uniform(10,20)
# Out:
# 12.121637872012332

# %%
random.randint(1,20)
# Out:
# 7

# %%
random.randrange(10,30,2)
# Out:
# 26

# %%
cards= ['nine', 'ace', 'jack', 'four', 'queen']
random.shuffle(cards)

# %%
cards
# Out:
# ['four', 'nine', 'queen', 'ace', 'jack']

# %%
random.choice(cards)
# Out:
# 'four'

# %%
random.choices(cards, k=3)
# Out:
# ['ace', 'jack', 'four']

# %%
random.normalvariate(mu=5, sigma=2.3)
# Out:
# 9.674310953780862

# %%
random.seed(456)

# %%
random.random()
# Out:
# 0.7482025358782363

# %%
random.randint(1,100)
# Out:
# 83
