# %%
class InsufficientBalanceError(Exception):
    pass


class ATM:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount
        else:
            raise InsufficientBalanceError("Insufficient balance")


account = ATM(5000)
account.withdraw(2000)
print("Balance:", account.balance)

account.withdraw(10000)  # raises InsufficientBalanceError
# Out:
# Balance: 3000
# ---------------------------------------------------------------------------
# InsufficientBalanceError                  Traceback (most recent call last)
# Cell In[3], line 20
#      16 account = ATM(5000)
#      17 account.withdraw(2000)
#      18 print("Balance:", account.balance)
#      19
# ---> 20 account.withdraw(10000)  # raises InsufficientBalanceError
#
# Cell In[3], line 13, in ATM.withdraw(self, amount)
#       9     def withdraw(self, amount):
#      10         if self.balance > amount:
#      11             self.balance -= amount
#      12         else:
# ---> 13             raise InsufficientBalanceError("Insufficient balance")
#
# InsufficientBalanceError: Insufficient balance

# %%
try:
    num=int(input("enter a number"))
    print(6/num)
except ValueError as e:
    print(e)
    print("invalid input")
    print(0)
except ZeroDivisionError as e:
    print(e)
    print("cant divide by zero")
except Exception as e:
    print("unknown error", e)
    print(0)
    
print("EoP")
# Out:
# division by zero
# cant divide by zero
# EoP

# %%
class InvalidAgeException(Exception):
    pass

def check_customer(age):
    
    if age >=18:
        print("good to go")
    else:
        raise InvalidAgeException("Must be greater than 18")

# %%
try:
    check_customer(
        int(input("enter age"))
    )

except InvalidAgeException as e:
    print("Transaction canceled")
    print(e)
    
except Exception as e:
    print("unknown error", e)
    print(0)
# Out:
# Transaction canceled
# Must be greater than 18
