# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\study material\\Project\\DSandML\\Week04'

# %%
if os.path.exists("test"):
    pass
else:
    print("file doesnt exist")
# Out:
# file doesnt exist

# %%
os.makedirs("test", exist_ok=True)

# %%
os.path.join("test", "file.txt")
# Out:
# 'test\\file.txt'

# %%
os.listdir()
# Out:
# ['Magic_methods.ipynb', 'OS_Module.ipynb', 'test']

# %%
os.listdrives()
# Out:
# ['C:\\', 'D:\\']

# %%
# import pprint 
  
# Get the list of user's 
env_var = os.environ 
print(env_var)

# Print the list of user's 
# print("User's Environment variable:") 
# pprint.pprint(dict(env_var), width = 1)
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\ProfessorScrew\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_STATSBEAT': 'true', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '133953359481477301', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_11900_QTTHQKJJBEKHXITG', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'WARMIND-RASPUTI', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONFIGSETROOT': 'C:\\WINDOWS\\ConfigSetRoot', 'COPILOT_OTEL_FILE_EXPORTER_PATH': '\\\\.\\nul', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_10892_1262719628': '1', 'EFC_10892_1592913036': '1', 'EFC_10892_2283032206': '1', 'EFC_10892_2775293581': '1', 'EFC_10892_3789132940': '1', 'EFC_10892_4126798990': '1', 'ELECTRON_RUN_AS_NODE': '1', 'HADOOP_HOME': 'C:\\hadoop\\bin', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\ProfessorScrew', 'JPY_INTERRUPT_EVENT': '2836', 'LOCALAPPDATA': 'C:\\Users\\ProfessorScrew\\AppData\\Local', 'LOGONSERVER': '\\\\WARMIND-RASPUTI', 'MSMPI_BENCHMARKS': 'C:\\Program Files\\Microsoft MPI\\Benchmarks\\', 'MSMPI_BIN': 'C:\\Program Files\\Microsoft MPI\\Bin\\', 'MXC_BIN_DIR': 'c:\\Users\\ProfessorScrew\\AppData\\Local\\Programs\\Microsoft VS Code\\a5b5009513\\resources\\app\\node_modules.asar.unpacked\\@microsoft\\mxc-sdk\\bin', 'NUMBER_OF_PROCESSORS': '20', 'ONEDRIVE': 'C:\\Users\\ProfessorScrew\\OneDrive', 'OS': 'Windows_NT', 'PATH': 'd:\\study material\\Project\\DSandML\\.venv\\Scripts;D:\\study material\\Project\\DS and ML\\.venv\\Scripts;C:\\app\\ProfessorScrew\\product\\26ai\\dbhomeFree\\bin;C:\\Python313\\Scripts\\;C:\\Python313\\;C:\\Program Files\\Common Files\\Oracle\\Java\\javapath;C:\\Program Files\\Microsoft MPI\\Bin\\;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\MinGW\\bin;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Git\\cmd;C:\\Program Files (x86)\\Microsoft SQL Server\\160\\Tools\\Binn\\;C:\\Program Files\\Microsoft SQL Server\\160\\Tools\\Binn\\;C:\\Program Files\\Microsoft SQL Server\\Client SDK\\ODBC\\170\\Tools\\Binn\\;C:\\Program Files\\Microsoft SQL Server\\160\\DTS\\Binn\\;C:\\Program Files (x86)\\Microsoft SQL Server\\160\\DTS\\Binn\\;C:\\Windows\\Microsoft.NET\\Framework\\v4.0.30319;C:\\Program Files\\Microsoft SQL Server\\150\\Tools\\Binn\\;C:\\Program Files\\nodejs\\;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files\\NVIDIA Corporation\\NVIDIA App\\NvDLISR;C:\\Program Files\\Cloudflare\\Cloudflare WARP\\;C:\\Program Files\\MongoDB\\Server\\8.2\\bin;C:\\Program Files\\Redis;C:\\hadoop\\bin;C:\\hadoop\\sbin;C:\\Users\\ProfessorScrew\\anaconda3;C:\\Users\\ProfessorScrew\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\ProfessorScrew\\anaconda3\\Library\\usr\\bin;C:\\Users\\ProfessorScrew\\anaconda3\\Library\\bin;C:\\Users\\ProfessorScrew\\anaconda3\\Scripts;C:\\Program Files\\Java\\jdk-24\\bin;C:\\Users\\ProfessorScrew\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\ProfessorScrew\\AppData\\Roaming\\npm;C:\\Users\\ProfessorScrew\\AppData\\Local\\GitHubDesktop\\bin;C:\\Program Files\\mongosh\\', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC;.PY;.PYW', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 154 Stepping 3, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': '9a03', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PROMPT': '(.venv) $P$G', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modul ...

# %%
os.environ["SECRETPass"]= "wasdferfqwgtrblahbsivewy12"
os.getenv("SECRETPass")
# Out:
# 'wasdferfqwgtrblahbsivewy12'

# %%
os.getenv("OneDrive")
# Out:
# 'C:\\Users\\ProfessorScrew\\OneDrive'
