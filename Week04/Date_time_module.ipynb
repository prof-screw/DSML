# %%
import datetime

# %%
birth_date=datetime.date(2003,9,18)

# %%
today= datetime.date.today()

# %%
age= today- birth_date

# %%
age.days
# Out:
# 8369

# %%
datetime.date.fromtimestamp(1786923143)
# Out:
# datetime.date(2026, 8, 17)

# %%
# from ast import NST


dt= datetime.datetime(2025,12,3,8,29,55, tzinfo= NST)
print(dt)
# Out:
# 2025-12-03 08:29:55+05:45

# %%
year_5= datetime.timedelta(days = 5*365)

# %%
NST= datetime.timezone(datetime.timedelta( hours= 5, minutes= 45))

# %%
import time

# %%
time.time()
# Out:
# 1787017675.953277

# %%
time.ctime()
# Out:
# 'Tue Aug 18 07:33:17 2026'

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=1, tm_min=48, tm_sec=27, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=7, tm_min=36, tm_sec=30, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
print("loading...")
time.sleep(5)
print("completed")
# Out:
# loading...
# completed

# %%
time.strftime("%H hour, %M minutes and %S seconds")
# Out:
# '07 hour, 40 minutes and 11 seconds'

# %%
start = time.time()

print("function started")
time.sleep(3)
print("function ended")

end= time.time()
# Out:
# function started
# function ended

# %%
end-start
# Out:
# 3.001382827758789
